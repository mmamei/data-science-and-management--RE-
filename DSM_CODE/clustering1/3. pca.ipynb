# %%
import pandas as pd
from sklearn import datasets
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('../dataset/iris.csv')
df.drop('Id', axis=1, inplace=True)
df.rename(columns={'Species': 'variety'}, inplace=True)

d = {v:i for i, v in enumerate(df['variety'].unique())}
df = df.replace(d)

X = df.drop(['variety'], axis='columns')
y = df['variety']

pca = PCA(n_components=2)
T = pca.fit_transform(X)
print(X[:2])
print(T[:2])
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# [[-2.68420713  0.32660731]
#  [-2.71539062 -0.16955685]]
# C:\Users\marco\AppData\Local\Temp\ipykernel_74688\1715636012.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(d)

# %%
colors = np.array(['red', 'blue', 'green'])
plt.scatter(T[:,0], T[:,1], color=colors[y])
plt.show()

# %%
pca = PCA(n_components=4)
T = pca.fit(X)
print(pca.explained_variance_ratio_)
# Out:
# [0.92461621 0.05301557 0.01718514 0.00518309]

# %%
pca = PCA(n_components=1)
T = pca.fit_transform(X)

plt.scatter(T, np.zeros_like(T), color=colors[y])
plt.show()
