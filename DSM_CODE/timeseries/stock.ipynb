# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including yfinance and matplotlib.

# %%
# Import the necessary libraries, including yfinance and matplotlib
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# # Set Up Yahoo Finance API
# Set up the Yahoo Finance API using the yfinance library.

# %%
# Set Up Yahoo Finance API

# Define the ticker symbol for the stock you want to download
ticker_symbol = 'TIT.MI'

# Use the yfinance library to download the stock data
start_date = '2022-01-01'
end_date = '2025-11-27'
stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)

# Display the first few rows of the downloaded data
stock_data.head()
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_45644\3009382108.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price        Close    High     Low    Open     Volume
# Ticker      TIT.MI  TIT.MI  TIT.MI  TIT.MI     TIT.MI
# Date
# 2022-01-03  0.4491  0.4550  0.4346  0.4359  120302219
# 2022-01-04  0.4449  0.4547  0.4449  0.4491   95071793
# 2022-01-05  0.4569  0.4607  0.4500  0.4542  155075630
# 2022-01-06  0.4518  0.4617  0.4510  0.4528   98819301
# 2022-01-07  0.4545  0.4565  0.4518  0.4551   80919027

# %%
stock_data.tail()
# Out:
# Price        Close    High     Low    Open     Volume
# Ticker      TIT.MI  TIT.MI  TIT.MI  TIT.MI     TIT.MI
# Date
# 2025-11-20  0.4898  0.4972  0.4807  0.4850  207264889
# 2025-11-21  0.4867  0.4885  0.4770  0.4830  169886333
# 2025-11-24  0.4964  0.5020  0.4880  0.4912  221109789
# 2025-11-25  0.4978  0.5020  0.4931  0.4980   93302197
# 2025-11-26  0.5008  0.5012  0.4932  0.5000  106995486

# %%
stock_data = stock_data.reset_index()

# %%
stock_data
# Out:
# Price        Date   Close    High     Low    Open     Volume
# Ticker             TIT.MI  TIT.MI  TIT.MI  TIT.MI     TIT.MI
# 0      2022-01-03  0.4491  0.4550  0.4346  0.4359  120302219
# 1      2022-01-04  0.4449  0.4547  0.4449  0.4491   95071793
# 2      2022-01-05  0.4569  0.4607  0.4500  0.4542  155075630
# 3      2022-01-06  0.4518  0.4617  0.4510  0.4528   98819301
# 4      2022-01-07  0.4545  0.4565  0.4518  0.4551   80919027
# ..            ...     ...     ...     ...     ...        ...
# 989    2025-11-20  0.4898  0.4972  0.4807  0.4850  207264889
# 990    2025-11-21  0.4867  0.4885  0.4770  0.4830  169886333
# 991    2025-11-24  0.4964  0.5020  0.4880  0.4912  221109789
# 992    2025-11-25  0.4978  0.5020  0.4931  0.4980   93302197
# 993    2025-11-26  0.5008  0.5012  0.4932  0.5000  106995486
#
# [994 rows x 6 columns]

# %%
stock_data.columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']
stock_data.head()
# Out:
#         Date   Close    High     Low    Open     Volume
# 0 2022-01-03  0.4491  0.4550  0.4346  0.4359  120302219
# 1 2022-01-04  0.4449  0.4547  0.4449  0.4491   95071793
# 2 2022-01-05  0.4569  0.4607  0.4500  0.4542  155075630
# 3 2022-01-06  0.4518  0.4617  0.4510  0.4528   98819301
# 4 2022-01-07  0.4545  0.4565  0.4518  0.4551   80919027

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994 entries, 0 to 993
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    994 non-null    datetime64[ns]
#  1   Close   994 non-null    float64
#  2   High    994 non-null    float64
#  3   Low     994 non-null    float64
#  4   Open    994 non-null    float64
#  5   Volume  994 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 46.7 KB

# %%
stock_data.tail()
# Out:
#           Date   Close    High     Low    Open     Volume
# 989 2025-11-20  0.4898  0.4972  0.4807  0.4850  207264889
# 990 2025-11-21  0.4867  0.4885  0.4770  0.4830  169886333
# 991 2025-11-24  0.4964  0.5020  0.4880  0.4912  221109789
# 992 2025-11-25  0.4978  0.5020  0.4931  0.4980   93302197
# 993 2025-11-26  0.5008  0.5012  0.4932  0.5000  106995486

# %% [markdown]
# # Visualize Stock Data
# Use matplotlib to visualize the downloaded stock timeseries data.

# %%
# Visualize Stock Data

# Plot the closing price of the stock
plt.figure(figsize=(10, 5))
plt.plot(stock_data['Date'], stock_data['Close'], label='Close Price')
plt.title(f'{ticker_symbol} Stock Closing Price')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# Plot the volume of the stock
plt.figure(figsize=(10, 5))
plt.plot(stock_data['Volume'], label='Volume', color='orange')
plt.title(f'{ticker_symbol} Stock Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.grid(True)
plt.show()

# %%
# https://medium.com/quant-factory/why-we-use-log-return-in-finance-349f8a2dc695#:~:text=Log%20returns%20are%20the%20logarithmic,asset%20at%20time%20t%2D
# https://web.archive.org/web/20221115013424/https://lucaslouca.com/Why-Use-Logarithmic-Returns-In-Time-Series-Modelling/
