# %%
import pandas as pd
df = pd.read_csv('01 - SuperStoreUS-2015.csv', sep=';')
df.groupby(['Product Category']).aggregate({'Sales':sum})
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_552\1457342271.py:3: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby(['Product Category']).aggregate({'Sales':sum})
#                       Sales
# Product Category
# Furniture         660704.31
# Office Supplies   551368.62
# Technology        712264.95
